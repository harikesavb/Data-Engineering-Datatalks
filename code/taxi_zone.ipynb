# %%
import pandas as pd

# %%
df=pd.read_csv('/workspaces/Data-Engineering-Datatalks/taxi_zone_lookup.csv')

# %%
dtype = {
    "Borough":"string",
     "Zone":"string",
    "service_zone":"string"
    
    
}

# %%
df.columns
# Out:
# Index(['LocationID', 'Borough', 'Zone', 'service_zone'], dtype='object')

# %%
df.dtypes
# Out:
# LocationID       int64
# Borough         object
# Zone            object
# service_zone    object
# dtype: object

# %%
len(df)
# Out:
# 265

# %%
df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
# !uv add sqlalchemy psycopg2-binary
# Out:
# Resolved 120 packages in 0.68ms
# Audited 13 packages in 0.22ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='home_work', con=engine))
# Out:
# CREATE TABLE home_work (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
df.head(n=0).to_sql(name='home_work', con=engine, if_exists='replace')
# Out:
# 0

# %%
# !uv add tqdm
# Out:
# Resolved 120 packages in 0.69ms
# Audited 13 packages in 0.21ms

# %%
df=pd.read_csv('/workspaces/Data-Engineering-Datatalks/taxi_zone_lookup.csv',
                iterator=True,
                chunksize=100000)

# %%
from tqdm.auto import tqdm

# %%
for itera in df:
    print(len(itera))
# Out:
# 265

# %%
itera.to_sql(name='home_work', con=engine, if_exists='append')
# Out:
# 265
